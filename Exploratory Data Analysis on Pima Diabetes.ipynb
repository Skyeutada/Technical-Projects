# %% [markdown]
# # Foundations of Data Science Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe. In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima tribe.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima Diabetes Analysis by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function that scores the likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome: Class variable (0: a person is not diabetic or 1: a person is diabetic)

# %% [markdown]
# ## Q 1: Import the necessary libraries and briefly explain the use of each library (3 Marks)

# %%
# remove _____ & write the appropriate library name

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 1:
# Numpy stands for ‘Numerical Python’.
# It is an essential package available on Python for Data Science and Data Analysis.
# It supports multi-dimensional arrays and other calculation functions.
#
# Pandas is derived from “Panel Data”.
# It is another useful and fundamental package on Python.
# It provides us with 2 main Data Structures: Series and DataFrame respectively.
# Both of these structures are useful for data cleaning and analysis.
#
# Usually when we talk about data visualization, we need to use Matplotlib and Seaborn.
#
# Matplotlib is originally from Matlab, another famous programming language developed by MathWorks.
# It helps us to plot different graphs such as pie charts, bar charts and histograms etc.
# .pyplot indicates its functions
#
# Seaborn is another library which is supplementary to Matplotlib. We need to rely on using it when we want to plot pair plots and heatmaps etc.

# %% [markdown]
# ## Q 2: Read the given dataset (1 Mark)

# %%
# remove _____ & write the appropriate function name

pima = pd.read_csv("C:\\Users\\Tin Chung\\Desktop\\MIT\\05 Foundations of Data Science\\diabetes.csv")

# %% [markdown]
# ## Q3. Show the last 10 records of the dataset. How many columns are there? (1 Mark)

# %%
# remove ______ and write the appropriate number in the function

pima.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76             20       79  37.5
# 759            6      190             92             20       79  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31       79  44.0
# 762            9       89             62             20       79  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27       79  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             20       79  30.1
# 767            1       93             70             31       79  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 3:
# There are 9 columns in total.

# %% [markdown]
# ## Q4. Show the first 10 records of the dataset (1 Mark)

# %%
# remove _____ & write the appropriate function name and the number of rows to get in the output

pima.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6      148             72             35       79  33.600000
# 1            1       85             66             29       79  26.600000
# 2            8      183             64             20       79  23.300000
# 3            1       89             66             23       94  28.100000
# 4            0      137             40             35      168  43.100000
# 5            5      116             74             20       79  25.600000
# 6            3       78             50             32       88  31.000000
# 7           10      115             69             20       79  35.300000
# 8            2      197             70             45      543  30.500000
# 9            8      125             96             20       79  31.992578
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# ...

# %% [markdown]
# ## Q5. What do you understand by the dimension of the dataset? Find the dimension of the `pima` dataframe. (1 Mark)

# %%
# remove _____ & write the appropriate function name

pima.shape
# Out:
# (768, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 5:
# The dimension of the dataset is a tuple consisted of 2 elements: The numbers of rows and columns respectively.
# There are 768 rows and 9 columns in this dataset.

# %% [markdown]
# ## Q6. What do you understand by the size of the dataset? Find the size of the `pima` dataframe. (1 Mark)

# %%
# remove _____ & write the appropriate function name

pima.size
# Out:
# 6912

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 6:
# The size of the dataset is basically the total number of elements in the data.
# The size in this case is 6912, which means there are 6912 elements in the dataset in total.

# %% [markdown]
# ## Q7. What are the data types of all the variables in the data set? (2 Marks)
# **Hint: Use the info() function to get all the information about the dataset.**

# %%
# remove _____ & write the appropriate function name

pima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 7:
# There are altogether 2 different data types - int64 (numerical values without a fractional part) and float64 (numerical values with decimal points)
# Only the columns of BMI and Diabetes Pedigree Function belong to the float64 type.
# The rest of the data is in integer form.

# %% [markdown]
# ## Q8. What do we mean by missing values? Are there any missing values in the `pima` dataframe? (2 Marks)

# %%
# remove _____ & write the appropriate function name

pima.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 8:
# The Missing value is any particular cell in the dataset without any given data.
# No information can be found from the cells.
# We can use .isnull() function to verify if there is any missing value.
# In our case the result is false, indicating that there are no missing values.

# %% [markdown]
# ## Q9. What do the summary statistics of the data represent? Find the summary statistics for all variables except 'Outcome' in the `pima` data. Take one column/variable from the output table and explain all its statistical measures. (3 Marks)

# %%
# remove _____ & write the appropriate function name

pima.iloc[:,0:8].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.675781      72.250000      26.447917  118.270833
# std       3.369578   30.436252      12.117203       9.733872   93.243829
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.000000   79.000000
# 50%       3.000000  117.000000      72.000000      23.000000   79.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    32.450805                  0.471876   33.240885
# std      6.875374                  0.331329   11.760232
# min     18.200000                  0.078000   21.000000
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 9:
# The summary statistics of the data represents basic and essential elements in descriptive statistics.
# Mean, Standard Deviation, Maximum and Minimum values and Interquartile Range can be found by applying the .describe() function.
#
# For the Age column, the minimum and maximum values are 21 and 81. It indicates a wide range of ages is included and examined in this dataset.
# However, the values of the 25th, 50th and 75th percentiles are 24, 29 and 41 respectively. That means most of the data in the Age column tend to lie in the younger age regions, while only a a handful of it belongs to the older age parts. If it is shown on a distribution plot, the curve will be right-skewed.
# we can then conclude that most of the data comes from women with younger age and only a small proportion is contributed by elderly.

# %% [markdown]
# ## Q 10. Plot the distribution plot for the variable 'BloodPressure'. Write detailed observations from the plot. (2 Marks)

# %%
# remove _____ & write the appropriate library name

sns.displot(pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 10:
# The shape shown on the distribution plot is almost as if the standard bell-shape curve of the normal distribution.
# The range of the blood pressure is from 20 to 120 approximately.
# A large proportion of the data is located and clustered at the centre of the graph.
# Since it is similar to the normal distribution, hence we can deduce that 95% of the data can be found within the range of Mu ± 2 Sigma.

# %% [markdown]
# ## Q 11. What is the 'BMI' of the person having the highest 'Glucose'? (1 Mark)

# %%
# remove _____ & write the appropriate function name


pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 11:The BMI of the person having the highest Glucose is 42.9.

# %% [markdown]
# ## Q12.
# ### 12.1 What is the mean of the variable 'BMI'?
# ### 12.2 What is the median of the variable 'BMI'?
# ### 12.3 What is the mode of the variable 'BMI'?
# ### 12.4 Are the three measures of central tendency equal?
#
# ### (3 Marks)

# %%
# remove _____ & write the appropriate function name

m1 = pima['BMI'].mean()  # mean
print(m1)
m2 = pima['BMI'].median()  # median
print(m2)
m3 = pima['BMI'].mode()[0]  # mode
print(m3)
# Out:
# 32.45080515543617
# 32.0
# 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 12:
# Yes, the three measures of central tendency are equal.

# %% [markdown]
# ## Q13. How many women's 'Glucose' levels are above the mean level of 'Glucose'? (1 Mark)

# %%
# remove _____ & write the appropriate function name

pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
# Out:
# 343

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 13:
# 343 women's Glucose levels are above the mean level of Glucose.

# %% [markdown]
# ## Q14. How many women have their 'BloodPressure' equal to the median of 'BloodPressure' and their 'BMI' less than the median of 'BMI'? (2 Marks)

# %%
# remove _____ & write the appropriate column name

pima[(pima['BloodPressure']==pima['BloodPressure'].median()) & (pima['BMI']<pima['BMI'].median())]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 14             5      166             72             19      175  25.8
# 93             4      134             72             20       79  23.8
# 103            1       81             72             18       40  26.6
# 205            5      111             72             28       79  23.9
# 299            8      112             72             20       79  23.6
# 325            1      157             72             21      168  25.6
# 330            8      118             72             19       79  23.1
# 366            6      124             72             20       79  27.6
# 380            1      107             72             30       82  30.8
# 393            4      116             72             12       87  22.1
# 406            4      115             72             20       79  28.9
# 446            1      100             72             12       70  25.3
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 14:
# The number of women is 22.

# %% [markdown]
# ## Q15. Create a pairplot for the variables 'Glucose', 'SkinThickness', and 'DiabetesPedigreeFunction'. Write your observations from the plot. (4 Marks)

# %%
# remove _____ & write the appropriate function name

sns.pairplot(data=pima,vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 15:
# The distribution of Glucose is as if a standard normal distribution one, it is clearly revealed on the upper left corner of the pair plot.
# On the other hands, both SkinThickness and DiabetesPedigreeFunction are right-skewed.
# No clear correlations can be found among these 3 factors because the slopes of the dot patterns are neither positive nor negative, indicating no positive and negative correlations.

# %% [markdown]
# ## Q16. Plot the scatterplot between 'Glucose' and 'Insulin'. Write your observations from the plot. (2 Marks)

# %%
# remove _____ & write the appropriate function name

sns.stripplot(x='Glucose',y='Insulin',data=pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 16:
# The larger the values of Glucose, the bigger the values of Insulin.
# They are directly proportional to each other.

# %% [markdown]
# ## Q 17. Plot the boxplot for the 'Age' variable. Are there outliers? (2 Marks)

# %%
# remove _____ & write the appropriate function and column name 

plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 17:
# The above boxplot clearly shows the presence of outliers above the horizontal line.
# They are above Age 65.

# %% [markdown]
# ## Q18. Plot histograms for the 'Age' variable to understand the number of women in different age groups given whether they have diabetes or not. Explain both histograms and compare them. (3 Marks)

# %%
# remove _____ & write the appropriate function and column name

plt.hist(pima[pima['Outcome']==1]['Age'], bins = 5)
plt.title('Distribution of Age for Women who has Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# remove _____ & write the appropriate function and column name

plt.hist(pima[pima['Outcome']==0]['Age'], bins = 5)
plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 18:
# The x-axis of both of the histograms represents the ranges of ages in the dataset.
# For the histogram of 'Distribution of Age for Women who has Diabetes', we can see that the youngest age group, which is 21-30 years old has the highest frequency of Diabetes.
# Then the older the age group, the fewer the cases of Diabetes can be found among them.
# 60-70 years old group has the fewest cases.
#
# But interestingly, the youngest group also has the most cases of not having the disease, and the number is significantly larger than that of other groups. Similarly, the older the age group, the fewer the cases of not having the disease.
#
# By comparison, we can see that the youngest group has the most cases of Diabetes, then the cases of each group decrease as the age gets older.

# %% [markdown]
# ## Q 19. What is the Interquartile Range of all the variables? Why is this used? Which plot visualizes the same? (2 Marks)

# %%
# remove _____ & write the appropriate variable name

Q1 = pima.quantile(0.25)
Q3 = pima.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Pregnancies                  5.0000
# Glucose                     40.5000
# BloodPressure               16.0000
# SkinThickness               12.0000
# Insulin                     48.2500
# BMI                          9.1000
# DiabetesPedigreeFunction     0.3825
# Age                         17.0000
# Outcome                      1.0000
# dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 19:
# The interquartile range of all the variables are
# Pregnancies: 5.0000
# Glucose: 40.5000
# BloodPressure: 16.0000
# SkinThickness: 12.0000
# Insulin: 48.2500
# BMI: 9.1000
# DiabetesPedigreeFunction: 0.3825
# Age: 17.0000
# Outcome: 1.0000
#
# The interquartile range is a measure in descriptive statistics for us to know the spread of the data.
# It is basically the difference between the 75th and 25th percentiles of the data. i.e. IQR = Q3- Q1
# It also shows us where the main part of the values of the data lies.
#
# Box plots visualize the same.

# %% [markdown]
# ## Q 20. Find and visualize the correlation matrix. Write your observations from the plot. (3 Marks)

# %%
# remove _____ & write the appropriate function name and run the code

corr_matrix = pima.iloc[:,0:8].corr()
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128022       0.208987       0.009393
# Glucose                      0.128022  1.000000       0.219765       0.158060
# BloodPressure                0.208987  0.219765       1.000000       0.130403
# SkinThickness                0.009393  0.158060       0.130403       1.000000
# Insulin                     -0.018780  0.396137       0.010492       0.245410
# BMI                          0.021546  0.231464       0.281222       0.532552
# DiabetesPedigreeFunction    -0.033523  0.137158       0.000471       0.157196
# Age                          0.544341  0.266673       0.326791       0.020582
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018780  0.021546                 -0.033523
# Glucose                   0.396137  0.231464                  0.137158
# ...

# %%
# remove _____ & write the appropriate function name

plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 20:
# The heatmap visualizes the correlation coefficients between the 8 factors in the rectangular table.
# We can see that most of the factors are basically negatively correlated to each other as their coefficients are tiny.
# However among all the coefficients, ‘Pregnancies and Age’, ‘Glucose and Insulin’ and ‘SkinThickness and BMI’ are positively correlated because their coefficients are much greater than that of the others.
